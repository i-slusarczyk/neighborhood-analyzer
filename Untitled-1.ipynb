# %%
import pandas as pd
import geopandas as gpd

# %%
gdf=gpd.read_file(r"D:\Foldery Użytkownika\Pobrane\export.geojson")

# %%
gdf.dropna(thresh=20).explore()
# Out:
#                     id                @id @relations bicycle   bus by_night  \
# 169   relation/6096022   relation/6096022       None    None  None     None
# 208   relation/9333762   relation/9333762       None    None  None     None
# 209   relation/9386914   relation/9386914       None    None  None     None
# 231   relation/9904453   relation/9904453       None    None  None     None
# 232   relation/9904454   relation/9904454       None    None  None     None
# 317  relation/11680206  relation/11680206       None    None  None     None
# 322  relation/11722662  relation/11722662       None    None  None     None
# 494  relation/17901868  relation/17901868       None    None  None     None
# 495  relation/17901869  relation/17901869       None    None  None     None
# 496  relation/17904667  relation/17904667       None    None  None     None
# 497  relation/17904668  relation/17904668       None    None  None     None
# ...
